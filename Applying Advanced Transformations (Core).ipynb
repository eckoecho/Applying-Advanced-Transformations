# %%
#Clean the files and combine them into one final DataFrame.
import pandas as pd
import json

# %%
#Importing the info csv and converting to df
info = pd.read_csv("Data/superhero_info - superhero_info.csv")
info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
#Importing the info csv and converting to df
powers = pd.read_csv("Data/superhero_powers - superhero_powers.csv")
powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
#Checking dtypes
powers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
## adding expand=True
info[["Hero","Publisher"]] = info["Hero|Publisher"].str.split("|", expand=True)
info
# Out:
#                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# 0             No Hair    yellow    Unknown
# ...

# %%
#Dropping column we split into 2
info.drop(columns="Hero|Publisher", inplace=True)
info
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color                                  Measurements             Hero  \
# ...

# %% [markdown]
# # Cleaning Measurement

# %%
## examining a single value from the measurements col 
# 0 indicates the row
specs = info.loc[0, "Measurements"]
print(type(specs))
# Out:
# <class 'str'>

# %%
specs
# Out:
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
## use .str.replace to replace all single quotes with double quotes
info["Measurements"] = info["Measurements"].str.replace("'", '"')
## use .str.replace to replace all single quotes with double quotes
info["Measurements"] = info["Measurements"].str.replace("'", '"')
## Apply the json.loads to the full column
info["Measurements"] = info["Measurements"].apply(json.loads)

# %%
info["Measurements"].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
#use the pandas pd.Series function on our column of dictionaries to turn into a new column
measurements = info["Measurements"].apply(pd.Series)
measurements
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
#Removing cm from height column, kg from weight
measurements["Height"] = measurements["Height"].str.replace(" cm","")
measurements["Weight"] = measurements["Weight"].str.replace(" kg","")
measurements[["Height", "Weight"]]
# Out:
#     Height Weight
# 0    203.0  441.0
# 1    191.0   65.0
# 2    185.0   90.0
# 3    203.0  441.0
# 4    193.0  122.0
# ..     ...    ...
# 458  183.0   83.0
# 459  165.0   52.0
# 460   66.0   17.0
# 461  170.0   57.0
# 462  185.0   81.0
#
# [463 rows x 2 columns]

# %%
#Converting string to float, then float to int
measurements[["Height", "Weight"]] = measurements[["Height", "Weight"]].astype("float")
measurements[["Height", "Weight"]] = measurements[["Height", "Weight"]].astype("int64")

# %%
# concat measurements with original dataframe
info = pd.concat((info, measurements), axis=1)
info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher  Height  Weight
# 0      Marvel Comics     203     441
# 1  Dark Horse Comics     191      65
# 2          DC Comics     185      90
# ...

# %%
#Drop measurements column
info = info.drop(columns = "Measurements")
#Ensuring Height and Weight are integers
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    int64
#  9   Weight      463 non-null    int64
# dtypes: int64(2), object(8)
# memory usage: 36.3+ KB

# %%
#Checking single value
super_power = powers.loc[1, "Powers"]
super_power
# Out:
# 'Accelerated Healing,Durability,Longevity,Super Strength,Stamina,Camouflage,Self-Sustenance'

# %%
# # Splitting at comma creates a list of values
powers["Powers_split"] = powers["Powers"].str.split(",")
powers[["Powers","Powers_split"]].head()
# Out:
#                                               Powers  \
# 0         Agility,Super Strength,Stamina,Super Speed
# 1  Accelerated Healing,Durability,Longevity,Super...
# 2  Agility,Accelerated Healing,Cold Resistance,Du...
# 3                                 Lantern Power Ring
# 4  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
## exploding the column of lists
exploded = powers.explode('Powers_split')
exploded.head(5)
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           Powers_split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
## saving the unique values from the exploded column
cols_to_make = exploded["Powers_split"].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in cols_to_make:
    powers[col] = powers["Powers"].str.contains(col)
    
powers
# Out:
# /var/folders/k6/7lk66pdn4_3f21m1dyjzs_dh0000gn/T/ipykernel_2641/2607193048.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers["Powers"].str.contains(col)
# /var/folders/k6/7lk66pdn4_3f21m1dyjzs_dh0000gn/T/ipykernel_2641/2607193048.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers[col] = powers["Powers"].str.contains(col)
# ...

# %%
# drop transactions clumns
powers = powers.drop(columns=['Powers','Powers_split'])
powers.head()
# Out:
#     hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# ...

# %% [markdown]
# # Use your combined DataFrame to answer the following questions.
#
# Compare the average weight of super powers who have Super Speed to those who do not.

# %% [markdown]
# ## Combine Info & Power DF

# %%
# concat measurements with original dataframe
df = pd.concat((info, powers), axis=1)
df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...           False
# 2       Abin Sur          DC Comics   185.0    90.0  ...           False
# 3    Abomination      Marvel Comics   203.0   441.0  ...           False
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %%
#number of super heros with Super Speed as power
super_speeders = powers["Super Speed"].sum()
super_speeders
# Out:
# 249

# %%
has_speed = powers["Super Speed"] == True
powers[has_speed]
# Out:
#        hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0         3-D Man     True            True     True         True
# 4     Abomination    False            True     True         True
# 5         Abraxas    False            True    False         True
# 8    Adam Strange    False           False    False         True
# 11     Air-Walker    False            True    False         True
# ..            ...      ...             ...      ...          ...
# 656   Wonder Girl     True            True    False         True
# 657    Wonder Man    False            True     True         True
# 658  Wonder Woman    False            True     True         True
# 664          Yoda     True           False     True         True
# 666          Zoom    False           False    False         True
#
#      Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                  False       False      False       False            False
# ...

# %%
powers["Weight"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weight'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#number of super heros that DO NOT have Super Speed as power
not_super_speeders = (powers["Super Speed"] == False).sum()
not_super_speeders

# %% [markdown]
# What is the average height of heroes for each publisher?
